# %% [markdown]
# Pull this out into the root for manual testing.

# %%
from app import dash_app

# %%
dash_app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# c:\temp\swmm-dash-mlflow\.venv\Lib\site-packages\swmmio\graphics\profiler.py:35: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# c:\temp\swmm-dash-mlflow\.venv\Lib\site-packages\swmmio\graphics\profiler.py:90: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# c:\temp\swmm-dash-mlflow\.venv\Lib\site-packages\swmmio\graphics\profiler.py:94: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# c:\temp\swmm-dash-mlflow\.venv\Lib\site-packages\swmmio\graphics\profiler.py:46: FutureWarning:
#
# ...
